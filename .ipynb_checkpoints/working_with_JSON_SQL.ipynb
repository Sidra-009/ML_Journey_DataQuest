# %%
# JSON(java script on notation) it is a universal format because all programming language understand this format
# when we fetch data from API  the data is in the json format used by java, python
# sql(database)
import pandas as pd

# %%
pd.read_json('train.json')
# Out:
#           id      cuisine                                        ingredients
# 0      10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1      25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2      20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3      22213       indian                [water, vegetable oil, wheat, salt]
# 4      13162       indian  [black pepper, shallots, cornflour, cayenne pe...
# ...      ...          ...                                                ...
# 39769  29109        irish  [light brown sugar, granulated sugar, butter, ...
# 39770  11462      italian  [KRAFT Zesty Italian Dressing, purple onion, b...
# 39771   2238        irish  [eggs, citrus fruit, raisins, sourdough starte...
# 39772  41882      chinese  [boneless chicken skinless thigh, minced garli...
# 39773   2362      mexican  [green chile, jalapeno chilies, onions, ground...
#
# [39774 rows x 3 columns]

# %%
pd.read_json('http://universities.hipolabs.com/search?country=Pakistan')
# Out:
#     alpha_two_code                                            domains  \
# 0               PK                                       [itu.edu.pk]
# 1               PK                                    [abasyn.edu.pk]
# 2               PK                                      [aiou.edu.pk]
# 3               PK                                      [ajku.edu.pk]
# 4               PK                                          [aku.edu]
# ..             ...                                                ...
# 131             PK                         [wahmedicalcollege.edu.pk]
# 132             PK                                    [zawiya.edu.pk]
# 133             PK                                    [mnsuet.edu.pk]
# 134             PK                                      [usms.edu.pk]
# 135             PK  [cusit.edu.pk, cityuniversity.edu.pk, cup.edu.pk]
#
#          state-province                               web_pages   country  \
# ...

# %%
# # -------------------------------
# # Example: Fetching Weather Data from OpenWeatherMap API
# # -------------------------------

# # In real-world scenarios, data engineers, data scientists, and analysts
# # follow similar steps to fetch data from APIs. The main steps are:
# # Find the API endpoint (from documentation)
# # Include required parameters (city, API key, units, etc.)
# # Make a request using 'requests' library
# # Parse the JSON response
# # Extract relevant information
# # Load into a DataFrame for analysis

# # import requests
# # import pandas as pd

# # -------------------------------
# # Step 1: Define the API endpoint URL
# # Replace 'YOUR_API_KEY' with the API key you get from OpenWeatherMap
# # 'q' parameter = city name
# # 'units' = metric for Celsius
# # url = "https://api.openweathermap.org/data/2.5/weather?q=Karachi&appid=YOUR_API_KEY&units=metric"

# # -------------------------------
# # Step 2: Send GET request to the API
# # requests.get() sends a request to the server and returns a response object
# # response = requests.get(url)

# # -------------------------------
# # Step 3: Parse the JSON response
# # Most APIs return data in JSON format, which is like a Python dictionary
# # data = response.json()

# # -------------------------------
# # Step 4: Extract useful information
# # We create a dictionary containing only the fields we want
# weather_info = {
#     "City": data["name"],                     # City name
#     "Temperature (°C)": data["main"]["temp"], # Current temperature
#     "Feels Like": data["main"]["feels_like"], # Feels like temperature
#     "Humidity": data["main"]["humidity"],     # Humidity %
#     "Condition": data["weather"][0]["description"] # Weather description
# }

# # -------------------------------
# # Step 5: Load into a Pandas DataFrame
# # DataFrames are very useful for data analysis and further processing
# df = pd.DataFrame([weather_info])

# # -------------------------------
# # Step 6: Display the DataFrame
# # In real projects, you can save it to CSV, Excel, or analyze directly
# print(df)

# %%
# fetching data from database SQL
import pandas as pd
import pyodbc

# %%
conn = pyodbc.connect(
    "Driver={ODBC Driver 17 for SQL Server};"
    "Server=DESKTOP-OHBVRQM\SQLEXPRESS;"          
    "Database=northwind;" 
    "Trusted_Connection=yes;"    
)

# %%
query = "SELECT TOP 50 * FROM [Order Details]"
df = pd.read_sql(query, conn)
df.head(50)
# Out:
# C:\Users\siddique traders\AppData\Local\Temp\ipykernel_23344\869474806.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
#     OrderID  ProductID  UnitPrice  Quantity  Discount
# 0     10248         11       14.0        12      0.00
# 1     10248         42        9.8        10      0.00
# 2     10248         72       34.8         5      0.00
# 3     10249         14       18.6         9      0.00
# 4     10249         51       42.4        40      0.00
# 5     10250         41        7.7        10      0.00
# 6     10250         51       42.4        35      0.15
# 7     10250         65       16.8        15      0.15
# 8     10251         22       16.8         6      0.05
# 9     10251         57       15.6        15      0.05
# 10    10251         65       16.8        20      0.00
# ...

# %%
import pyodbc
conn = pyodbc.connect(
    "Driver={ODBC Driver 17 for SQL Server};"
    "Server=DESKTOP-OHBVRQM\SQLEXPRESS;"          
    "Database=northwind;" 
    "Trusted_Connection=yes;"    
)

# %%
query = "SELECT * FROM Employees WHERE [Title] LIKE 'Sales Representative'"
df = pd.read_sql(query, conn)
df.head()
# Out:
# C:\Users\siddique traders\AppData\Local\Temp\ipykernel_23344\3167114899.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
#    EmployeeID   LastName FirstName                 Title TitleOfCourtesy  \
# 0           1    Davolio     Nancy  Sales Representative             Ms.
# 1           3  Leverling     Janet  Sales Representative             Ms.
# 2           4    Peacock  Margaret  Sales Representative            Mrs.
# 3           6     Suyama   Michael  Sales Representative             Mr.
# 4           7       King    Robert  Sales Representative             Mr.
#
#    BirthDate   HireDate                           Address      City Region  \
# 0 1948-12-08 1992-05-01     507 - 20th Ave. E.\r\nApt. 2A   Seattle     WA
# ...

# %%
# conn=mysql.connector .connect(host='if remote server put the ip address here(eg.aws) ',user='',dataset='databasename')

# %%
# automatically creates pandas data frame
# pd.read_sql_query('select * from city ',conn)
