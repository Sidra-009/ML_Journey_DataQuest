# %%
#importing pandas 
import pandas as pd

# %%
# opening a local csv file
df = pd.read_csv('Pakistan_Flood_Data_By_NDMA.csv')
df
# Out:
#         Region  Total deaths  M_D  F_D  C_D  total_injured   M_I   F_I   C_I  \
# 0         AJ&K            48   31   17    0             24    15     9     0
# 1  Balochistan           299  136   73   90            181    92    40    49
# 2           GB            22    5   11    6              6     3     0     3
# 3          ICT             1    1    0    0              0     0     0     0
# 4           KP           306  149   41  116            369   156    79   134
# 5       Punjab           191   94   47   50           3858  2173   113   572
# 6        Sindh           678  262  126  290           8422  2954  2211  3247
#
#    Roads_damaged(km)  Bridges damaged  Total_houses_damaged  \
# 0                  0                0                   548
# 1               1850               22                 65997
# 2                 16               65                  1211
# 3                  0                0                     0
# ...

# %%
# OPENING A CSV FILE FROM URL
# from fetching github server (request.get) fetches all the content of the file
import requests
from io import StringIO

url = "https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv"
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/140.0.0.0 Safari/537.36"}
req = requests.get(url, headers=headers)
data = StringIO(req.text)

pd.read_csv(data)
# Out:
#        Country         Region
# 0      Algeria         AFRICA
# 1       Angola         AFRICA
# 2        Benin         AFRICA
# 3     Botswana         AFRICA
# 4      Burkina         AFRICA
# ..         ...            ...
# 189   Paraguay  SOUTH AMERICA
# 190       Peru  SOUTH AMERICA
# 191   Suriname  SOUTH AMERICA
# 192    Uruguay  SOUTH AMERICA
# 193  Venezuela  SOUTH AMERICA
#
# [194 rows x 2 columns]

# %%
# https://github.com/srbh24/NLP/blob/master/movie_review_test.csv
import requests
from io import StringIO

url = "https://raw.githubusercontent.com/srbh24/NLP/master/movie_review_test.csv"
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/140.0.0.0 Safari/537.36"}
req = requests.get(url, headers=headers)
data = StringIO(req.text)

pd.read_csv(data)
# Out:
#     class                                               text
# 0     Pos   films adapted from comic books have had plent...
# 1     Pos   every now and then a movie comes along from a...
# 2     Pos   you ve got mail works alot better than it des...
# 3     Pos      jaws   is a rare film that grabs your atte...
# 4     Pos   moviemaking is a lot like being the general m...
# ..    ...                                                ...
# 395   Neg   one of the first films of 1999 is this mtv pi...
# 396   Neg   susan granger s review of   america s sweethe...
# 397   Neg   susan granger s review of   jeepers creepers ...
# 398   Neg   this independent film written and directed by...
# 399   Neg   come on hollywood   surprise me    stop givin...
#
# [400 rows x 2 columns]

# %%
# Sep Parameter by using sep 
# if first row become column (if column name is not available then you pass a list with columns name) for eg(names=['sno','review','liked']
pd.read_csv('Restaurant_Reviews.tsv',sep='\t')
# Out:
#                                                 Review  Liked
# 0                             Wow... Loved this place.      1
# 1                                   Crust is not good.      0
# 2            Not tasty and the texture was just nasty.      0
# 3    Stopped by during the late May bank holiday of...      1
# 4    The selection on the menu was great and so wer...      1
# ..                                                 ...    ...
# 995  I think food should have flavor and texture an...      0
# 996                           Appetite instantly gone.      0
# 997  Overall I was not impressed and would not go b...      0
# 998  The whole experience was underwhelming, and I ...      0
# 999  Then, as if I hadn't wasted enough of my life ...      0
#
# [1000 rows x 2 columns]

# %%
# index_col_parameter in my data there is 2 indexes so i convert my sno into index
pd.read_csv('Salary_Data.csv',index_col='sno')
# Out:
#      YearsExperience  Salary
# sno
# 0                1.1   39343
# 1                1.3   46205
# 2                1.5   37731
# 3                2.0   43525
# 4                2.2   39891
# 5                2.9   56642
# 6                3.0   60150
# 7                3.2   54445
# 8                3.2   64445
# 9                3.7   57189
# 10               3.9   63218
# 11               4.0   55794
# 12               4.0   56957
# 13               4.1   57081
# 14               4.5   61111
# 15               4.9   67938
# 16               5.1   66029
# 17               5.3   83088
# 18               5.9   81363
# 19               6.0   93940
# 20               6.8   91738
# 21               7.1   98273
# 22               7.9  101302
# 23               8.2  113812
# 24               8.7  109431
# 25               9.0  105582
# 26               9.5  116969
# 27               9.6  112635
# 28              10.3  122391
# 29              10.5  121872

# %%
# header parameter(when first row is the column name since a person who genrated csv they put column 0 infront of row, pamdas do not understand that this is not normal row these are columns header we use (header=1)
# pd.read_csv('Data.csv',header=1)
# this uses when we have no columns names and column names are treated like rows

# %%
# use_cols_parameters
# when we have a dataset we not necessarily use all the colmns , when the time of importing data we specify columns name then others columns are automatically removed

# %%
pd.read_csv('DataScience_salaries_2024.csv')
# Out:
#        work_year experience_level employment_type  \
# 0           2021               MI              FT
# 1           2021               MI              FT
# 2           2020               MI              FT
# 3           2021               MI              FT
# 4           2022               SE              FT
# ...          ...              ...             ...
# 14833       2022               MI              FT
# 14834       2020               EX              FT
# 14835       2021               EN              FT
# 14836       2022               EN              FT
# 14837       2020               EN              PT
#
#                              job_title    salary salary_currency  \
# 0                       Data Scientist  30400000             CLP
# 1                      BI Data Analyst  11000000             HUF
# 2                       Data Scientist  11000000             HUF
# 3                          ML Engineer   8500000             JPY
# ...

# %%
#if i want only 3 or more cols we pass a parameter name usecols
pd.read_csv('DataScience_salaries_2024.csv',usecols=['job_title','salary','experience_level'])
# Out:
#       experience_level                        job_title    salary
# 0                   MI                   Data Scientist  30400000
# 1                   MI                  BI Data Analyst  11000000
# 2                   MI                   Data Scientist  11000000
# 3                   MI                      ML Engineer   8500000
# 4                   SE   Lead Machine Learning Engineer   7500000
# ...                ...                              ...       ...
# 14833               MI  Business Intelligence Developer     15000
# 14834               EX               Staff Data Analyst     15000
# 14835               EN       Machine Learning Developer     15000
# 14836               EN                     Data Analyst     15000
# 14837               EN                      ML Engineer     14000
#
# [14838 rows x 3 columns]

# %%
#squeeze parameter Pandas v2.0 removed so i used this for series
pd.read_csv('DataScience_salaries_2024.csv',usecols=['job_title'])['job_title']
# Out:
# 0                         Data Scientist
# 1                        BI Data Analyst
# 2                         Data Scientist
# 3                            ML Engineer
# 4         Lead Machine Learning Engineer
#                       ...
# 14833    Business Intelligence Developer
# 14834                 Staff Data Analyst
# 14835         Machine Learning Developer
# 14836                       Data Analyst
# 14837                        ML Engineer
# Name: job_title, Length: 14838, dtype: object

# %%
# skiprows/nrows parameter (the values we give those particular rows we skip)
# pd.read_csv('DataScience_salaries_2024.csv',skiprows=[0,4])

# %%
# skiprows/nrows parameter 
pd.read_csv('DataScience_salaries_2024.csv',nrows=100)
# Out:
#     work_year experience_level employment_type  \
# 0        2021               MI              FT
# 1        2021               MI              FT
# 2        2020               MI              FT
# 3        2021               MI              FT
# 4        2022               SE              FT
# ..        ...              ...             ...
# 95       2023               MI              FT
# 96       2024               SE              FT
# 97       2024               SE              FT
# 98       2024               SE              FT
# 99       2023               EX              FT
#
#                          job_title    salary salary_currency  salary_in_usd  \
# 0                   Data Scientist  30400000             CLP          40038
# 1                  BI Data Analyst  11000000             HUF          36259
# 2                   Data Scientist  11000000             HUF          35735
# 3                      ML Engineer   8500000             JPY          77364
# ...

# %%
#encoding parameter
pd.read_csv('kaggle Netflix Movies and TV Shows.csv',encoding="latin1")
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
# 8807   s8808  TV Show     Parasyte: The Grey     Yeon Sang-ho
# 8808   s8809    Movie                 Serena     Susanne Bier
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
# skip bad lines if csv have 5 col or rows have 6 or 8 values
# pd.read_csv('BX-books.csv',sep=';',encoding='latin-1',error_bad_lines=False)

# %%
#dtypes parameters
df=pd.read_csv('Fortune 500 Companies US.csv',encoding_errors='ignore')

# %%
#there are some values in previous rank is nan so i run this code 
df["Previous Rank"] = df["Previous Rank"].fillna(0).astype(int)

# %%
df
# Out:
#      Rank        Company Name Number of Employees  Previous Rank   Revenues  \
# 0       1             Walmart           23,00,000              1  $4,85,873
# 1       2  Berkshire Hathaway            3,67,700              4  $2,23,604
# 2       3               Apple            1,16,000              3  $2,15,639
# 3       4         Exxon Mobil              72,700              2  $2,05,004
# 4       5            McKesson              68,000              5  $1,92,487
# ..    ...                 ...                 ...            ...        ...
# 495   496       Michaels Cos.              31,000            517     $5,197
# 496   497       Toll Brothers               4,200            576     $5,170
# 497   498               Yahoo               8,500            513     $5,169
# 498   499       Vistra Energy               4,431              0     $5,164
# 499   500      ABM Industries            1,10,000            485     $5,145
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Rank                 500 non-null    int64
#  1   Company Name         500 non-null    object
#  2   Number of Employees  500 non-null    object
#  3   Previous Rank        500 non-null    int32
#  4   Revenues             500 non-null    object
#  5   Revenue Change       500 non-null    object
#  6   Profits              500 non-null    object
#  7   Profit Change        500 non-null    object
#  8   Assets               500 non-null    object
#  9   Market Value         500 non-null    object
# dtypes: int32(1), int64(1), object(8)
# memory usage: 37.2+ KB

# %%
import pandas as pd
#handlin dates
data=pd.read_csv('DataScience_salaries_2024.csv',parse_dates=['work_year'])

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14838 entries, 0 to 14837
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           14838 non-null  datetime64[ns]
#  1   experience_level    14838 non-null  object
#  2   employment_type     14838 non-null  object
#  3   job_title           14838 non-null  object
#  4   salary              14838 non-null  int64
#  5   salary_currency     14838 non-null  object
#  6   salary_in_usd       14838 non-null  int64
#  7   employee_residence  14838 non-null  object
#  8   remote_ratio        14838 non-null  int64
#  9   company_location    14838 non-null  object
#  10  company_size        14838 non-null  object
# dtypes: datetime64[ns](1), int64(3), object(7)
# memory usage: 1.2+ MB

# %%
def rename(name):
    if name=='BI Data Analyst':
        return "BI DA"
    else:
        return name

# %%
rename("BI Data Analyst")
# Out:
# 'BI DA'

# %%
#convertors
pd.read_csv('DataScience_salaries_2024.csv',converters={'job_title':rename})
# Out:
#        work_year experience_level employment_type  \
# 0           2021               MI              FT
# 1           2021               MI              FT
# 2           2020               MI              FT
# 3           2021               MI              FT
# 4           2022               SE              FT
# ...          ...              ...             ...
# 14833       2022               MI              FT
# 14834       2020               EX              FT
# 14835       2021               EN              FT
# 14836       2022               EN              FT
# 14837       2020               EN              PT
#
#                              job_title    salary salary_currency  \
# 0                       Data Scientist  30400000             CLP
# 1                                BI DA  11000000             HUF
# 2                       Data Scientist  11000000             HUF
# 3                          ML Engineer   8500000             JPY
# ...

# %%
#na_values parameters
pd.read_csv("DataScience_salaries_2024.csv",na_values=['Machine Learning Developer'])
# Out:
#        work_year experience_level employment_type  \
# 0           2021               MI              FT
# 1           2021               MI              FT
# 2           2020               MI              FT
# 3           2021               MI              FT
# 4           2022               SE              FT
# ...          ...              ...             ...
# 14833       2022               MI              FT
# 14834       2020               EX              FT
# 14835       2021               EN              FT
# 14836       2022               EN              FT
# 14837       2020               EN              PT
#
#                              job_title    salary salary_currency  \
# 0                       Data Scientist  30400000             CLP
# 1                      BI Data Analyst  11000000             HUF
# 2                       Data Scientist  11000000             HUF
# 3                          ML Engineer   8500000             JPY
# ...

# %% [raw]
# # LOADING A HUGE DATASET IN CHUNKS
# dfs=pd.read_csv("DataScience_salaries_2024.csv",chunksize=5000)

# %%
# LOADING A HUGE DATASET IN CHUNKS
# df=pd.read_csv("DataScience_salaries_2024.csv",chunksize=5000)

# %%
df = pd.read_csv("DataScience_salaries_2024.csv", chunksize=5000)

for chunk in df:
    print(chunk.shape)
# Out:
# (5000, 11)
# (5000, 11)
# (4838, 11)
